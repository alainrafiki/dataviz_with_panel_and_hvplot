# %%
import pandas as pd
import numpy as np
import panel as pn
pn.extension('tabulator') 
# More on this here: https://panel.holoviz.org/reference/widgets/Tabulator.html

import hvplot.pandas
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='7e162f8e-02fe-42d6-b52a-1526922a1164'>
#   <div id="b885fbd0-7151-49bb-a313-7c0d07eb7d8e" data-root-id="7e162f8e-02fe-42d6-b52a-1526922a1164" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"eefe92cc-3a49-4c0a-b5c1-8d07fe07b837":{"version":"3.3.0","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"7e162f8e-02fe-42d6-b52a-1526922a1164"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"e21bfa13-f766-42db-a515-99dd80ac3c52","attributes":{"plot_id":"7e162f8e-02fe-42d6-b52a-1526922a1164","comm_id":"18d7440291b24a2aad5b38e478fbac59","client_comm_id":"1ca3bf23d9a3458b94a15864184c1ef9"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"toggle_value1","properties":[{"name":"active_icons","kind":"Any","default":{"type":"map"}},{"name":"options","kind":"Any","default":{"type":"map","entries":[["favorite","heart"]]}},{"name":"value","kind":"Any","default":[]},{"name":"_reactions","kind":"Any","default":[]},{"name":"_base_url","kind":"Any","default":"https://tabler-icons.io/static/tabler-icons/icons/"}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"value","kind":"Any","default":null},{"name":"fill","kind":"Any","default":"none"}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"nam ...
#   var render_items = [{"docid":"eefe92cc-3a49-4c0a-b5c1-8d07fe07b837","roots":{"7e162f8e-02fe-42d6-b52a-1526922a1164":"b885fbd0-7151-49bb-a313-7c0d07eb7d8e"},"root_ids":["7e162f8e-02fe-42d6-b52a-1526922a1164"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   const is_dev = py_version.indexOf("+") !== -1 || py_version.indexOf("-") !== -1
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version && !is_dev) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined && ( root['Tabulator'] !== undefined) && ( root['Tabulator'] !== undefined) && ( root['Tabulator'] !== undefined) && ( root['Tabulator'] !== undefined) && ( root['Tabulator'] !== undefined) && ( root['Tabulator'] !== undefined) && ( root['Tabulator'] !== undefined) && ( root['Tabulator'] !== undefined) && ( root['Tabulator'] !== undefined))
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
# Grab some data from Our World in Data. Go to https://github.com/owid/co2-data/blob/master/owid-co2-data.csv and grab the raw data.
df = pd.read_csv('https://raw.githubusercontent.com/owid/co2-data/master/owid-co2-data.csv')

# %%
df
# Out:
#            country  year  ... trade_co2  trade_co2_share
# 0      Afghanistan  1850  ...       NaN              NaN
# 1      Afghanistan  1851  ...       NaN              NaN
# 2      Afghanistan  1852  ...       NaN              NaN
# 3      Afghanistan  1853  ...       NaN              NaN
# 4      Afghanistan  1854  ...       NaN              NaN
# ...            ...   ...  ...       ...              ...
# 50593     Zimbabwe  2017  ...     0.910            9.486
# 50594     Zimbabwe  2018  ...     0.771            6.537
# 50595     Zimbabwe  2019  ...     0.978            8.795
# 50596     Zimbabwe  2020  ...     1.006            9.481
# 50597     Zimbabwe  2021  ...       NaN              NaN
#
# [50598 rows x 79 columns]

# %%
df.columns
# Out:
# Index(['country', 'year', 'iso_code', 'population', 'gdp', 'cement_co2',
#        'cement_co2_per_capita', 'co2', 'co2_growth_abs', 'co2_growth_prct',
#        'co2_including_luc', 'co2_including_luc_growth_abs',
#        'co2_including_luc_growth_prct', 'co2_including_luc_per_capita',
#        'co2_including_luc_per_gdp', 'co2_including_luc_per_unit_energy',
#        'co2_per_capita', 'co2_per_gdp', 'co2_per_unit_energy', 'coal_co2',
#        'coal_co2_per_capita', 'consumption_co2', 'consumption_co2_per_capita',
#        'consumption_co2_per_gdp', 'cumulative_cement_co2', 'cumulative_co2',
#        'cumulative_co2_including_luc', 'cumulative_coal_co2',
#        'cumulative_flaring_co2', 'cumulative_gas_co2', 'cumulative_luc_co2',
#        'cumulative_oil_co2', 'cumulative_other_co2', 'energy_per_capita',
#        'energy_per_gdp', 'flaring_co2', 'flaring_co2_per_capita', 'gas_co2',
#        'gas_co2_per_capita', 'ghg_excluding_lucf_per_capita', 'ghg_per_capita',
#        'land_use_change_co2', 'land_use_change_co2_per_capita', 'methane',
#        'methane_per_capita', 'nitrous_oxide', 'nitrous_oxide_per_capita',
#        'oil_co2', 'oil_co2_per_capita', 'other_co2_per_capita',
#        'other_industry_co2', 'primary_energy_consumption',
#        'share_global_cement_co2', 'share_global_co2',
#        'share_global_co2_including_luc', 'share_global_coal_co2',
#        'share_global_cumulative_cement_co2', 'share_global_cumulative_co2',
#        'share_global_cumulative_co2_including_luc',
#        'share_global_cumulative_coal_co2',
#        'share_global_cumulative_flaring_co2',
#        'share_global_cumulative_gas_co2', 'share_global_cumulative_luc_co2',
#        'share_global_cumulative_oil_co2', 'share_global_cumulative_other_co2',
#        'share_global_flaring_co2', 'share_global_gas_co2',
#        'share_global_luc_co2', 'share_global_oil_co2',
#        'share_global_other_co2', 'share_of_temperature_change_from_ghg',
#        'temperature_change_from_ch4', 'temperature_change_from_co2',
#        'temperature_change_from_ghg', 'temperature_change_from_n2o',
#        'total_ghg', 'total_ghg_excluding_lucf', 'trade_co2',
#        'trade_co2_share'],
#       dtype='object')

# %%
df[df['country'] == 'World']
# Out:
#       country  year  ... trade_co2  trade_co2_share
# 49810   World  1750  ...       NaN              NaN
# 49811   World  1751  ...       NaN              NaN
# 49812   World  1752  ...       NaN              NaN
# 49813   World  1753  ...       NaN              NaN
# 49814   World  1754  ...       NaN              NaN
# ...       ...   ...  ...       ...              ...
# 50077   World  2017  ...     0.004              0.0
# 50078   World  2018  ...    -0.004             -0.0
# 50079   World  2019  ...     0.000              0.0
# 50080   World  2020  ...     0.000              0.0
# 50081   World  2021  ...     0.000              0.0
#
# [272 rows x 79 columns]

# %% [markdown]
# # Data Clean Up

# %%
# Fill NAs with 0s and create GDP per capita column
df = df.fillna(0)
df['gdp_per_capita'] = np.where(df['population']!=0, df['gdp']/df['population'],0)

# %%
# Make dataframe pipeline interactive
idf = df.interactive()

# %% [markdown]
# # CO2 emission over time per continent

# %%
# Define the Panel widgets
# Find out more widgets here: panel.holoviz.org/user_guide/Widgets.html
year_slider = pn.widgets.IntSlider(name='Year Slider', start=1750, end=2020, step=5, value=1850)
year_slider
# Out:
# IntSlider(end=2020, name='Year Slider', start=1750, step=5, value=1850)

# %%
# Radio buttons for CO2 measures
yaxis_co2 = pn.widgets.RadioButtonGroup(
    name = 'Y axis',
    options = ['co2', 'co2_per_capita',],
    button_type = 'success'
)

# %%
# Let's create a CO2 Data Pipeline
continents = ['World', 'Asia', 'Oceania', 'Europe', 'Africa', 'North America', 'South America', 'Antarctica' ]

co2_pipeline = (
    idf[
        (idf.year <= year_slider) &
        (idf.country.isin(continents))
    ]
    .groupby(['country', 'year'])[yaxis_co2].mean()
    .to_frame()
    .reset_index()
    .sort_values(by='year')
    .reset_index(drop=True)
)

# %%
# Here is what the data pipeline looks like
co2_pipeline.head(n=10)
# Out:
# <div id='266bf272-905d-4e10-88db-f67077a480e4'>
#   <div id="c0f20b25-e9a2-48c2-8c39-e14830e6ee33" data-root-id="266bf272-905d-4e10-88db-f67077a480e4" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"4a1e5110-d8e4-425d-977f-9ab7238e86e3":{"version":"3.3.0","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"266bf272-905d-4e10-88db-f67077a480e4","attributes":{"name":"Row30251","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"542ee6ba-fcb3-4566-87a9-7d84eba7c82d","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.1/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"3e02b946-8cbf-4f18-a247-d82ca0d7ee68","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.1/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"109b10eb-85b3-45a3-a845-3e5158cdde0a","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.1/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"39c09b97-24bf-4251-9011-91521c8e72b5","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.1/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"bc1685e9-6f06-4408-ab3c-39dd315f2a38","attributes":{"name":"Column30248","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"542ee6ba-fcb3-4566-87a9-7d84eba7c82d"},{"id":"3e02b946-8cbf-4f18-a247-d82ca0d7ee68"},{"id":"109b10eb-85b3-45a3-a845-3e5158cdde0a"},{"id":"39c09b97-24bf-4251-9011-91521c8e72b5"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"23419d29-5b8f-42f5-a0f4-760d6573a768","attributes":{"name":"Column30218","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"542ee6ba-fcb3-4566-87a9-7d84eba7c82d"},{"id":"3e02b946-8cbf-4f18-a247-d82ca0d7ee68"},{"id":"109b10eb-85b3-45a3-a845-3e5158cdde0a"},{"id":"39c09b97-24bf-4251-9011-91521c8e72b5"}],"margin":0,"align":"start","children":[{"type":"object","name":"Slider","id":"5d184757-01ab-4a81-a34e-326cdd0fa2bc","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"542ee6ba-fcb3-4566-87a9-7d84eba7c82d"},{"id":"109b10eb-85b3-45a3-a845-3e5158cdde0a"},{"id":"39c09b97-24bf-4251-9011-91521c8e72b5"}],"margin":[5,10],"align":"start","title":"Year Slider","start":1750,"end":2020,"value":2020,"step":5}},{"type":"object","name":"panel.models.widgets.RadioButtonGroup","id":"5b5337ff-d465-4e71-8a2a-a998170bd659","attributes":{"button_type":"success","css_classes":["solid"],"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"542ee6ba-fcb3-4566-87a9-7d84eba7c82d"},{"type":"object","name":"ImportedStyleSheet","id":"4cdbe522-971c-43f9-98ca-4443afc67692","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.1/dist/css/button.css"}},{"id":"109b10eb-85b3-45a3-a845-3e5158cdde0a"},{"id":"39c09b97-24bf-4251-9011-91521c8e72b5"}],"margin":[5,10],"align":"start","labels":["co2","co2_per_capita"],"active":0}}]}},{"type":"object","name":"panel.models.layout.Column","id":"1ad4447b-33ff-495d-81ed-05342ef32a5b","attributes":{"name":"Column30233","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"542ee6ba-fcb3-4566-87a9-7d84eba7c82d"},{"id":"3e02b946-8cbf-4f18-a247-d82ca0d7ee68"},{"id":"109b10eb-85b3-45a3-a845-3e5158cdde0a"},{"id":" ...

# %%
# Here is a plot of the data pipeline
co2_plot = co2_pipeline.hvplot(x = 'year', by = 'country', y=yaxis_co2, line_width=2, title = 'CO2 Emission by Continent')
co2_plot
# Out:
# <div id='d9b72ebc-b0ca-47b5-bc27-4a64a4aa4931'>
#   <div id="a8b05256-4026-4e42-9225-87029a8458c6" data-root-id="d9b72ebc-b0ca-47b5-bc27-4a64a4aa4931" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"e27eaf4c-6908-4b19-9ffd-ee88d32e7cc8":{"version":"3.3.0","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"d9b72ebc-b0ca-47b5-bc27-4a64a4aa4931","attributes":{"name":"Row30683","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"d50c09a7-5b7a-4b1b-8f5e-364ca38ea853","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.1/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"d98bd8c9-bed3-4743-8654-3e44db9bcd80","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.1/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"1c0e1728-1955-4e5f-8e3b-bc59f7443ff2","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.1/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"befe5a28-c0f0-4fbd-aff2-55f95985f361","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.1/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"fc5c15d7-7c4e-43f2-aad7-f5eaff39e249","attributes":{"name":"Column30680","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"d50c09a7-5b7a-4b1b-8f5e-364ca38ea853"},{"id":"d98bd8c9-bed3-4743-8654-3e44db9bcd80"},{"id":"1c0e1728-1955-4e5f-8e3b-bc59f7443ff2"},{"id":"befe5a28-c0f0-4fbd-aff2-55f95985f361"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"0c6bea8f-f09c-445e-95d6-f95bf0639b2e","attributes":{"name":"Column30663","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"d50c09a7-5b7a-4b1b-8f5e-364ca38ea853"},{"id":"d98bd8c9-bed3-4743-8654-3e44db9bcd80"},{"id":"1c0e1728-1955-4e5f-8e3b-bc59f7443ff2"},{"id":"befe5a28-c0f0-4fbd-aff2-55f95985f361"}],"margin":0,"align":"start","children":[{"type":"object","name":"Slider","id":"83b63569-202d-4051-8a6b-f8ef1fe7f3a4","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"d50c09a7-5b7a-4b1b-8f5e-364ca38ea853"},{"id":"1c0e1728-1955-4e5f-8e3b-bc59f7443ff2"},{"id":"befe5a28-c0f0-4fbd-aff2-55f95985f361"}],"margin":[5,10],"align":"start","title":"Year Slider","start":1750,"end":2020,"value":2020,"step":5}},{"type":"object","name":"panel.models.widgets.RadioButtonGroup","id":"3e00d5eb-98b5-4dbb-8c2e-eb7d8cdb1a6e","attributes":{"button_type":"success","css_classes":["solid"],"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"d50c09a7-5b7a-4b1b-8f5e-364ca38ea853"},{"type":"object","name":"ImportedStyleSheet","id":"8cce3e4c-55c6-490b-ae0c-da7522464837","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.1/dist/css/button.css"}},{"id":"1c0e1728-1955-4e5f-8e3b-bc59f7443ff2"},{"id":"befe5a28-c0f0-4fbd-aff2-55f95985f361"}],"margin":[5,10],"align":"start","labels":["co2","co2_per_capita"],"active":0}}]}},{"type":"object","name":"Figure","id":"07188193-8b1b-4144-a5f4-25c4506451df","attributes":{"width":700,"height":300,"margin":[5,10],"sizing_mode":"fixed","align":"start","x_range":{"type":"object","name":"Range1d","id":"061bd409-bfe7-428f-9142-58446c19ea16","attributes":{"tags":[[["year","year",null]],[]],"start":1750.0,"end":2020.0,"reset_start":1750.0,"reset_end":2020.0}},"y_range":{"type":"object","name":"Range1d","id":"61890008-f54e-4ff2-b378-cffd3de9b70d","attr ...

# %% [markdown]
# # Table of CO2 Emission Over Time By Continent

# %%
co2_table = co2_pipeline.pipe(pn.widgets.Tabulator, pagination='remote', page_size = 10, sizing_mode='stretch_width')
co2_table
# Out:
# <div id='8eef18f0-a03c-4679-8aba-9a21440543ba'>
#   <div id="fed97784-e1b8-4c16-8c61-3ad1a45acf93" data-root-id="8eef18f0-a03c-4679-8aba-9a21440543ba" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"09539c58-f04a-4901-ad33-988f91f2b78e":{"version":"3.3.0","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"8eef18f0-a03c-4679-8aba-9a21440543ba","attributes":{"name":"Row33819","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"1a530b3a-a99a-4abf-8153-fa526dbfb2d8","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.1/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"1f313c9f-30cc-4447-8bc3-db9b023d102a","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.1/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"682fb355-3c24-4df0-ad2b-2844b1ed046c","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.1/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"f888eba8-ae7e-4e7f-be4a-f97d2829e3b0","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.1/dist/bundled/theme/native.css"}}],"margin":0,"sizing_mode":"stretch_width","align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"c43976c7-f364-4ea8-85d4-991d0ecbfc97","attributes":{"name":"Column33816","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"1a530b3a-a99a-4abf-8153-fa526dbfb2d8"},{"id":"1f313c9f-30cc-4447-8bc3-db9b023d102a"},{"id":"682fb355-3c24-4df0-ad2b-2844b1ed046c"},{"id":"f888eba8-ae7e-4e7f-be4a-f97d2829e3b0"}],"margin":0,"sizing_mode":"stretch_width","align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"c89e0397-9241-4ee1-9ee0-4ee554656c3c","attributes":{"name":"Column33798","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"1a530b3a-a99a-4abf-8153-fa526dbfb2d8"},{"id":"1f313c9f-30cc-4447-8bc3-db9b023d102a"},{"id":"682fb355-3c24-4df0-ad2b-2844b1ed046c"},{"id":"f888eba8-ae7e-4e7f-be4a-f97d2829e3b0"}],"margin":0,"align":"start","children":[{"type":"object","name":"Slider","id":"bd304427-2e37-41e9-9481-82a36f78ede8","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"1a530b3a-a99a-4abf-8153-fa526dbfb2d8"},{"id":"682fb355-3c24-4df0-ad2b-2844b1ed046c"},{"id":"f888eba8-ae7e-4e7f-be4a-f97d2829e3b0"}],"margin":[5,10],"align":"start","title":"Year Slider","start":1750,"end":2020,"value":2020,"step":5}},{"type":"object","name":"panel.models.widgets.RadioButtonGroup","id":"4220d349-b864-453f-b3eb-50bfc276086e","attributes":{"button_type":"success","css_classes":["solid"],"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"1a530b3a-a99a-4abf-8153-fa526dbfb2d8"},{"type":"object","name":"ImportedStyleSheet","id":"9c9d4c71-6ad9-4de6-a71f-c6246a662aa5","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.1/dist/css/button.css"}},{"id":"682fb355-3c24-4df0-ad2b-2844b1ed046c"},{"id":"f888eba8-ae7e-4e7f-be4a-f97d2829e3b0"}],"margin":[5,10],"align":"start","labels":["co2","co2_per_capita"],"active":0}}]}},{"type":"object","name":"panel.models.layout.Column","id":"0e895592-8885-475d-81cb-0faee8111cdc","attributes":{"name":"Column33813","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"1a530b3a-a99a-4abf-8153-fa526dbfb2d8"},{"id":"1f313c9f-30cc-4447-8bc3-db9b023d ...

# %%
# Let's build a new timeline for CO2 vs. GDP. 
# We will look at countries and not continents this time.

co2_vs_gdp_scatterplot_pipeline = (
    idf[
        (idf.year == year_slider) &
        (~ (idf.country.isin(continents)))
    ]
    .groupby(['country', 'year', 'gdp_per_capita'])['co2'].mean()
    .to_frame()
    .reset_index()
    .sort_values(by='year')
    .reset_index(drop=True)
)

# %%
# Quick preview of the head of the pipeline
co2_vs_gdp_scatterplot_pipeline.head(n=15)
# Out:
# <div id='1d508bec-e726-4db5-b8c7-1a02864ff446'>
#   <div id="d0f3646f-ec2e-48d5-93c9-3cfc861bb2d6" data-root-id="1d508bec-e726-4db5-b8c7-1a02864ff446" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"4eaf1113-8be5-41c1-b0f0-bf220780e557":{"version":"3.3.0","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"1d508bec-e726-4db5-b8c7-1a02864ff446","attributes":{"name":"Row67883","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"fe9f749f-60ed-4b51-88b0-41b4261dfc4b","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.1/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"d1a3bc98-8544-4203-9fab-95f2489b9c98","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.1/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"84aa078b-de24-4c94-a6c8-6fc3793172ce","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.1/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"960a50dd-62b7-47c6-b87e-6830438d8318","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.1/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"bd2c9e54-68ec-42e9-bd08-7b6eb29ed955","attributes":{"name":"Column67880","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"fe9f749f-60ed-4b51-88b0-41b4261dfc4b"},{"id":"d1a3bc98-8544-4203-9fab-95f2489b9c98"},{"id":"84aa078b-de24-4c94-a6c8-6fc3793172ce"},{"id":"960a50dd-62b7-47c6-b87e-6830438d8318"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"fc0bf7a0-50a6-42f5-b4bb-b0485ec22dfe","attributes":{"name":"Column67850","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"fe9f749f-60ed-4b51-88b0-41b4261dfc4b"},{"id":"d1a3bc98-8544-4203-9fab-95f2489b9c98"},{"id":"84aa078b-de24-4c94-a6c8-6fc3793172ce"},{"id":"960a50dd-62b7-47c6-b87e-6830438d8318"}],"margin":0,"align":"start","children":[{"type":"object","name":"Slider","id":"d127b764-9d0d-4aa3-89ac-0f71bc02b922","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"fe9f749f-60ed-4b51-88b0-41b4261dfc4b"},{"id":"84aa078b-de24-4c94-a6c8-6fc3793172ce"},{"id":"960a50dd-62b7-47c6-b87e-6830438d8318"}],"margin":[5,10],"align":"start","title":"Year Slider","start":1750,"end":2020,"value":1790,"step":5}}]}},{"type":"object","name":"panel.models.layout.Column","id":"535ac614-1326-49d4-96e8-1c9b4c3f8c2a","attributes":{"name":"Column67865","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"fe9f749f-60ed-4b51-88b0-41b4261dfc4b"},{"id":"d1a3bc98-8544-4203-9fab-95f2489b9c98"},{"id":"84aa078b-de24-4c94-a6c8-6fc3793172ce"},{"id":"960a50dd-62b7-47c6-b87e-6830438d8318"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.markup.HTML","id":"5835ccdf-bb8b-442b-a2fe-d4124a94480a","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"fe9f749f-60ed-4b51-88b0-41b4261dfc4b"},{"type":"object","name":"ImportedStyleSheet","id":"a3ee909a-7e84-40f9-874d-9a7c0adc5a0a","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.1/dist/css/dataframe.css"}},{"id":"84aa078b-de24-4c94-a6c8-6fc3793172ce"},{"id":"960a50dd-62b7-47c6-b87e-6830438d8318"}],"margin":[5,10],"align":"start","text":"&lt;table class=&q ...

# %%
# Now let's build the scatterplot that's based on the pipeline above
co2_vs_gdp_scatterplot = co2_vs_gdp_scatterplot_pipeline.hvplot(x = 'gdp_per_capita', y = 'co2', by = 'country', size = 80, kind = 'scatter', alpha = 0.7, legend = False, height = 500, width = 500)

# View the scatterplot
co2_vs_gdp_scatterplot
# Out:
# <div id='fcba38fb-9b23-41e6-86e7-90c81882a625'>
#   <div id="df30198e-89f7-4002-9ce9-48274e62297b" data-root-id="fcba38fb-9b23-41e6-86e7-90c81882a625" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"f5c3d1af-aca3-40d7-8320-c1b9a962eb1a":{"version":"3.3.0","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"fcba38fb-9b23-41e6-86e7-90c81882a625","attributes":{"name":"Row68695","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"ff50687e-1c6e-4418-bba3-70baf07208a9","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.1/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"d0c0901b-b811-41d5-9a88-9e146392d9c5","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.1/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"28e6c22a-efb9-4375-ba0c-65980f856d07","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.1/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"f310c76d-226a-49ee-ada6-d0594dd1b4e5","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.1/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"c42549db-4d92-4f00-aa56-e90e9f4a648d","attributes":{"name":"Column68692","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"ff50687e-1c6e-4418-bba3-70baf07208a9"},{"id":"d0c0901b-b811-41d5-9a88-9e146392d9c5"},{"id":"28e6c22a-efb9-4375-ba0c-65980f856d07"},{"id":"f310c76d-226a-49ee-ada6-d0594dd1b4e5"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"3da5b9f2-55d9-46a6-be5a-f4b53d064a73","attributes":{"name":"Column68675","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"ff50687e-1c6e-4418-bba3-70baf07208a9"},{"id":"d0c0901b-b811-41d5-9a88-9e146392d9c5"},{"id":"28e6c22a-efb9-4375-ba0c-65980f856d07"},{"id":"f310c76d-226a-49ee-ada6-d0594dd1b4e5"}],"margin":0,"align":"start","children":[{"type":"object","name":"Slider","id":"71dbdd17-33b4-4a0f-85e4-49f30e6067dc","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"ff50687e-1c6e-4418-bba3-70baf07208a9"},{"id":"28e6c22a-efb9-4375-ba0c-65980f856d07"},{"id":"f310c76d-226a-49ee-ada6-d0594dd1b4e5"}],"margin":[5,10],"align":"start","title":"Year Slider","start":1750,"end":2020,"value":1790,"step":5}}]}},{"type":"object","name":"Figure","id":"b3d077ce-77cb-41a4-93af-ce13956c1e04","attributes":{"width":500,"height":500,"margin":[5,10],"sizing_mode":"fixed","align":"start","x_range":{"type":"object","name":"Range1d","id":"68f18a9b-e50e-44b1-b890-3c875edd0b46","attributes":{"tags":[[["gdp_per_capita","gdp_per_capita",null]],[]],"start":-1.2,"end":1.2,"reset_start":-1.2,"reset_end":1.2}},"y_range":{"type":"object","name":"Range1d","id":"caeaf970-1524-47b1-b353-b14fa15e0831","attributes":{"tags":[[["co2","co2",null]],{"type":"map","entries":[["invert_yaxis",false],["autorange",false]]}],"start":-1.9177,"end":21.0947,"reset_start":-1.9177,"reset_end":21.0947}},"x_scale":{"type":"object","name":"LinearScale","id":"89b37d0c-a908-4cd5-ae95-52a0a47c9f88"},"y_scale":{"type":"object","name":"LinearScale","id":"786ee040-4ac0-476e-867c-21308900d1ca"},"title":{"type":"object","name":"Title","id":"1939aa72-5e7e-409b-97d9-fac3feec3ff8","attributes":{"text_color":"black","text_font_size":"12pt"}},"renderers":[{"type":"object","name":"GlyphRenderer","id":"eea048ed-d686-4402-a108-b3787ced96a6","attributes":{"data_source":{"type":"object","name":"ColumnDataSource","id":"2e765ce6-b080-48fb-a37f-11e90a45399f","attributes":{ ...

# %% [markdown]
# # Bar Chart with CO2 Sources by Continent

# %%
yaxis_co2_source = pn.widgets.RadioButtonGroup(
    name = 'Y axis',
    options = ['coal_co2', 'oil_co2', 'gas_co2'],
    button_type = 'success'
)

continents_excl_world = ['Asia', 'Oceania', 'Europe', 'Africa', 'North America', 'South America', 'Antarctica' ]
co2_source_bar_pipeline = (
    idf[
        (idf.year == year_slider) &
        (idf.country.isin(continents_excl_world))
    ]
    .groupby(['year', 'country'])[yaxis_co2_source].sum()
    .to_frame()
    .reset_index()
    .sort_values(by='year')
    .reset_index(drop=True)
)

# %%
co2_source_bar_plot = co2_source_bar_pipeline.hvplot(kind = 'bar', x = 'country', y = yaxis_co2_source, title = 'CO2 Source by Continent')
co2_source_bar_plot
# Out:
# <div id='d3fc2ae0-abc3-41a7-a54d-a634b47b2bb7'>
#   <div id="d0ed346d-14fc-4245-ab8f-16c853991397" data-root-id="d3fc2ae0-abc3-41a7-a54d-a634b47b2bb7" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"853fbea1-4ba4-413d-8318-aeccd6f8f115":{"version":"3.3.0","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"d3fc2ae0-abc3-41a7-a54d-a634b47b2bb7","attributes":{"name":"Row151205","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"6ff0165e-9b21-40ca-a079-a1864b0fa131","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.1/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"a61e2348-d932-41dd-92b2-afebb3dcc49e","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.1/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"4997880f-d33a-45d0-9c10-df9d70773d3e","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.1/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"ceff0ca7-796a-4a65-906d-e11ec2e17325","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.1/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"fbae9185-7047-49ec-b7e3-8b128f4f3759","attributes":{"name":"Column151202","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"6ff0165e-9b21-40ca-a079-a1864b0fa131"},{"id":"a61e2348-d932-41dd-92b2-afebb3dcc49e"},{"id":"4997880f-d33a-45d0-9c10-df9d70773d3e"},{"id":"ceff0ca7-796a-4a65-906d-e11ec2e17325"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"ca7c7d14-68ec-4a2d-802f-187b756c2cc3","attributes":{"name":"Column151185","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"6ff0165e-9b21-40ca-a079-a1864b0fa131"},{"id":"a61e2348-d932-41dd-92b2-afebb3dcc49e"},{"id":"4997880f-d33a-45d0-9c10-df9d70773d3e"},{"id":"ceff0ca7-796a-4a65-906d-e11ec2e17325"}],"margin":0,"align":"start","children":[{"type":"object","name":"Slider","id":"0b56762a-9b1c-4779-a0c0-23d53815ca8f","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"6ff0165e-9b21-40ca-a079-a1864b0fa131"},{"id":"4997880f-d33a-45d0-9c10-df9d70773d3e"},{"id":"ceff0ca7-796a-4a65-906d-e11ec2e17325"}],"margin":[5,10],"align":"start","title":"Year Slider","start":1750,"end":2020,"value":1960,"step":5}},{"type":"object","name":"panel.models.widgets.RadioButtonGroup","id":"5c60e973-8f1f-4e5a-9ce6-bd9e9edd1ed2","attributes":{"button_type":"success","css_classes":["solid"],"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"6ff0165e-9b21-40ca-a079-a1864b0fa131"},{"type":"object","name":"ImportedStyleSheet","id":"d01ce2bc-7089-4f51-9691-3e6e8c2dd839","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.1/dist/css/button.css"}},{"id":"4997880f-d33a-45d0-9c10-df9d70773d3e"},{"id":"ceff0ca7-796a-4a65-906d-e11ec2e17325"}],"margin":[5,10],"align":"start","labels":["coal_co2","oil_co2","gas_co2"],"active":1}}]}},{"type":"object","name":"Figure","id":"d11926ad-a3a6-41db-a7db-87c16718add7","attributes":{"width":700,"height":300,"margin":[5,10],"sizing_mode":"fixed","align":"start","x_range":{"type":"object","name":"FactorRange","id":"d8b46455-7186-45b3-ad25-b639521556a3","attributes":{"tags":[[["country","country",null]],[]],"factors":["Africa","Antarctica","Asia","Europe","North America","Oceania","South America"]}},"y_range":{"type":"object","name":"Range1d","id" ...

# %% [markdown]
# # Let's Create the Dashboard

# %%
# Layout using the FastListTemplate
# More on the template here: https://panel.holoviz.org/reference/templates/FastListTemplate.html

template = pn.template.FastListTemplate(
    title = 'World CO2 Emission Dashboard',
    sidebar = [
        pn.pane.Markdown("# CO2 Emissions and Climate Change"),
        pn.pane.Markdown("#### Carbon dioxide emissions are believed to be the primary drivers of global climate change."),
        pn.pane.PNG('img/randomimage.png', sizing_mode = 'scale_both'),
        pn.pane.Markdown("## Settings"),
        year_slider],
    main = [
        pn.Row(pn.Column(yaxis_co2, co2_plot.panel(width=700), margin=(0,25)), 
               co2_table.panel(width=500)),
        pn.Row(pn.Column(co2_vs_gdp_scatterplot.panel(width=600), margin=(0,25)),
              pn.Column(yaxis_co2_source, co2_source_bar_plot.panel(width=600)))
    ],
    accent_base_color = "#88d8b0",
    header_background = "#88d8b0",
)

# Time to display the dashboard
template.servable();

# %% [markdown]
# # Launch the Dashboard via Terminal
#
# At this point in the process, go to the terminal. Preferably in the same virtual environment as this notebook. If possible, use the terminal console in this instance of Jupyter Lab where the notebook is live. After typing "panel serve thisnotebookname.ipynb" in the terminal, there should come a URL in the terminal that you can then copy and paste in a browser to vide the dashboards.
